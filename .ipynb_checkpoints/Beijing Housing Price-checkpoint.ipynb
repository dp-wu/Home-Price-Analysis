# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import figure
import seaborn as sns

# %%
# read csv file
beijing = pd.read_csv('new.csv', encoding = 'unicode_escape', low_memory=False)

# %% [markdown]
# ### A Glance

# %% [markdown]
# **Context** Housing price of Beijing from *2011* to *2017*, fetching from Lianjia.com

# %%
# take a look at the data
beijing.head(1)
# Out:
#                                                  url            id  \
# 0  https://bj.lianjia.com/chengjiao/101084782030....  101084782030
#
#           Lng       Lat            Cid   tradeTime     DOM  followers  \
# 0  116.475489  40.01952  1111027376244  2016-08-09  1464.0        106
#
#    totalPrice  price        ...         buildingType constructionTime  \
# 0       415.0  31680        ...                  1.0             2005
#
#   renovationCondition  buildingStructure ladderRatio elevator  \
# 0                   3                  6       0.217      1.0
#
#    fiveYearsProperty subway  district  communityAverage
# 0                0.0    1.0         7           56021.0
#
# [1 rows x 26 columns]

# %%
beijing.shape
# Out:
# (318851, 26)

# %%
beijing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318851 entries, 0 to 318850
# Data columns (total 26 columns):
# url                    318851 non-null object
# id                     318851 non-null object
# Lng                    318851 non-null float64
# Lat                    318851 non-null float64
# Cid                    318851 non-null int64
# tradeTime              318851 non-null object
# DOM                    160874 non-null float64
# followers              318851 non-null int64
# totalPrice             318851 non-null float64
# price                  318851 non-null int64
# square                 318851 non-null float64
# livingRoom             318851 non-null object
# drawingRoom            318851 non-null object
# kitchen                318851 non-null int64
# bathRoom               318851 non-null object
# floor                  318851 non-null object
# buildingType           316830 non-null float64
# constructionTime       318851 non-null object
# renovationCondition    318851 non-null int64
# buildingStructure      318851 non-null int64
# ladderRatio            318851 non-null float64
# elevator               318819 non-null float64
# fiveYearsProperty      318819 non-null float64
# subway                 318819 non-null float64
# district               318851 non-null int64
# communityAverage       318388 non-null float64
# dtypes: float64(11), int64(7), object(8)
# memory usage: 63.2+ MB

# %%
beijing.describe()
# it is pretty abnormal having min value 0.1 for totalPrice and 1 for price/sqrm
# Out:
#                  Lng            Lat           Cid            DOM  \
# count  318851.000000  318851.000000  3.188510e+05  160874.000000
# mean      116.418459      39.949591  1.129113e+12      28.822339
# std         0.112054       0.091983  2.363447e+12      50.237343
# min       116.072514      39.627030  1.111027e+12       1.000000
# 25%       116.344985      39.893200  1.111027e+12       1.000000
# 50%       116.416780      39.934527  1.111027e+12       6.000000
# 75%       116.477581      40.003018  1.111027e+12      37.000000
# max       116.732378      40.252758  1.114620e+15    1677.000000
#
#            followers     totalPrice          price         square  \
# count  318851.000000  318851.000000  318851.000000  318851.000000
# mean       16.731508     349.030201   43530.436379      83.240597
# std        34.209185     230.780778   21709.024204      37.234661
# min         0.000000       0.100000       1.000000       6.900000
# 25%         0.000000     205.000000   28050.000000      57.900000
# 50%         5.000000     294.000000   38737.000000      74.260000
# 75%        18.000000     425.500000   53819.500000      98.710000
# max      1143.000000   18130.000000  156250.000000    1745.500000
#
#              kitchen   buildingType  renovationCondition  buildingStructure  \
# count  318851.000000  316830.000000        318851.000000      318851.000000
# mean        0.994599       3.009790             2.606330           4.451026
# std         0.109609       1.269857             1.311739           1.901753
# min         0.000000       0.048000             0.000000           0.000000
# 25%         1.000000       1.000000             1.000000           2.000000
# 50%         1.000000       4.000000             3.000000           6.000000
# 75%         1.000000       4.000000             4.000000           6.000000
# max         4.000000       4.000000             4.000000           6.000000
#
#         ladderRatio       elevator  fiveYearsProperty         subway  \
# count  3.188510e+05  318819.000000      318819.000000  318819.000000
# mean   6.316486e+01       0.577055           0.645601       0.601112
# std    2.506851e+04       0.494028           0.478331       0.489670
# min    0.000000e+00       0.000000           0.000000       0.000000
# 25%    2.500000e-01       0.000000           0.000000       0.000000
# 50%    3.330000e-01       1.000000           1.000000       1.000000
# 75%    5.000000e-01       1.000000           1.000000       1.000000
# max    1.000940e+07       1.000000           1.000000       1.000000
#
#             district  communityAverage
# count  318851.000000     318388.000000
# mean        6.763564      63682.446305
# std         2.812616      22329.215447
# min         1.000000      10847.000000
# 25%         6.000000      46339.000000
# 50%         7.000000      59015.000000
# 75%         8.000000      75950.000000
# max        13.000000     183109.000000

# %%
# drop url column since the id column is unique identifier for each instance
print(beijing.url.nunique() == beijing.id.nunique() == beijing.shape[0])
df = beijing.drop(['url'], axis=1)

# reset id column as index of the table
df.set_index(['id'], inplace=True)
# convert time series data to datetime type
df['tradeTime'] = pd.to_datetime(df['tradeTime'])

# remove na from constructionTime column and temporarily set them mean respect to the district.
# if the the prediction isn't good, I will do further modification of it
df['constructionTime'] = pd.to_numeric(df.constructionTime.astype(str).str.replace(',',''), errors='coerce')
df['constructionTime'] = df.groupby(['district'])['constructionTime'].transform(lambda x: x.fillna(x.mean())).astype(int) 
# take a look at the column names now
print(df.columns)
# Out:
# True
# Index(['Lng', 'Lat', 'Cid', 'tradeTime', 'DOM', 'followers', 'totalPrice',
#        'price', 'square', 'livingRoom', 'drawingRoom', 'kitchen', 'bathRoom',
#        'floor', 'buildingType', 'constructionTime', 'renovationCondition',
#        'buildingStructure', 'ladderRatio', 'elevator', 'fiveYearsProperty',
#        'subway', 'district', 'communityAverage'],
#       dtype='object')

# %%
# look for columns containing NaN type information
print(df.isna().any())
# Out:
# Lng                    False
# Lat                    False
# Cid                    False
# tradeTime              False
# DOM                     True
# followers              False
# totalPrice             False
# price                  False
# square                 False
# livingRoom             False
# drawingRoom            False
# kitchen                False
# bathRoom               False
# floor                  False
# buildingType            True
# constructionTime       False
# renovationCondition    False
# buildingStructure      False
# ladderRatio            False
# elevator                True
# fiveYearsProperty       True
# subway                  True
# district               False
# communityAverage        True
# dtype: bool

# %%
# we are going to take a look at these columns (with DOM info)
temp1 = df[['DOM', 'buildingType', 'elevator', 'fiveYearsProperty', 'subway', 'communityAverage']]
temp1_null = temp1[pd.isnull(temp1).any(axis=1)]
temp1_null.shape
# Out:
# (159475, 6)

# %%
print('column name: (# of nulls in the temp1 df,  # of nulls in the original df)')
print('buildingType: (', temp1_null.buildingType.isnull().sum(), ', ', 318851 - 316830, ')')
print('elevator: (', temp1_null.elevator.isnull().sum(), ', ', 318851 - 318819, ')')
print('fiveYearsProperty: (', temp1_null.fiveYearsProperty.isnull().sum(), ', ', 318851 - 318819, ')')
print('subway: (', temp1_null.subway.isnull().sum(), ', ', 318851 - 318819, ')')
print('communityAverage: (', temp1_null.communityAverage.isnull().sum(), ', ', 318851 - 318388, ')')
# Out:
# column name: (# of nulls in the temp1 df,  # of nulls in the original df)
# buildingType: ( 2021 ,  2021 )
# elevator: ( 32 ,  32 )
# fiveYearsProperty: ( 32 ,  32 )
# subway: ( 32 ,  32 )
# communityAverage: ( 463 ,  463 )

# %%
# columns containing NaN values (without DOM info)
temp2 = df[['buildingType', 'elevator', 'fiveYearsProperty', 'subway', 'communityAverage']]
temp2_null = temp2[pd.isnull(temp2).any(axis=1)]
temp2_null.shape
# Out:
# (2403, 5)

# %%
print('column name: (# of nulls in the temp1 df,  # of nulls in the original df)')
print('buildingType: (', temp2_null.buildingType.isnull().sum(), ', ', 318851 - 316830, ')')
print('elevator: (', temp2_null.elevator.isnull().sum(), ', ', 318851 - 318819, ')')
print('fiveYearsProperty: (', temp2_null.fiveYearsProperty.isnull().sum(), ', ', 318851 - 318819, ')')
print('subway: (', temp2_null.subway.isnull().sum(), ', ', 318851 - 318819, ')')
print('communityAverage: (', temp2_null.communityAverage.isnull().sum(), ', ', 318851 - 318388, ')')
# Out:
# column name: (# of nulls in the temp1 df,  # of nulls in the original df)
# buildingType: ( 2021 ,  2021 )
# elevator: ( 32 ,  32 )
# fiveYearsProperty: ( 32 ,  32 )
# subway: ( 32 ,  32 )
# communityAverage: ( 463 ,  463 )

# %%
temp2_null.describe()
# Out:
#        buildingType     elevator  fiveYearsProperty       subway  \
# count    382.000000  2371.000000        2371.000000  2371.000000
# mean       2.745296     0.198650           0.500633     0.396457
# std        1.333256     0.399068           0.500105     0.489265
# min        0.048000     0.000000           0.000000     0.000000
# 25%        2.000000     0.000000           0.000000     0.000000
# 50%        3.000000     0.000000           1.000000     0.000000
# 75%        4.000000     0.000000           1.000000     1.000000
# max        4.000000     1.000000           1.000000     1.000000
#
#        communityAverage
# count       1940.000000
# mean       47100.667526
# std        19381.038030
# min        20483.000000
# 25%        34781.000000
# 50%        43245.000000
# 75%        54892.000000
# max       183109.000000

# %%
# columns containing NaN values (without DOM info)
temp3 = df[['buildingType', 'elevator', 'fiveYearsProperty', 'subway', 'communityAverage']]
temp3_null = temp3[pd.isnull(temp3[['elevator', 'fiveYearsProperty', 'subway']]).any(axis=1)]
temp3_null
# Out:
#               buildingType  elevator  fiveYearsProperty  subway  \
# id
# BJ0000615040         0.500       NaN                NaN     NaN
# BJ0000615084         0.333       NaN                NaN     NaN
# BJ0000615132         0.333       NaN                NaN     NaN
# BJ0000615138         0.500       NaN                NaN     NaN
# BJ0000615208         0.125       NaN                NaN     NaN
# BJ0000615220         0.500       NaN                NaN     NaN
# BJ0000615222         0.500       NaN                NaN     NaN
# BJ0000615229         0.333       NaN                NaN     NaN
# BJ0000615401         0.500       NaN                NaN     NaN
# BJ0000615438         0.125       NaN                NaN     NaN
# BJ0000615469         0.333       NaN                NaN     NaN
# BJ0000615595         0.500       NaN                NaN     NaN
# BJ0000615621         0.250       NaN                NaN     NaN
# BJ0000615635         0.500       NaN                NaN     NaN
# BJ0000615823         0.250       NaN                NaN     NaN
# BJ0000615998         0.500       NaN                NaN     NaN
# BJ0000616423         0.500       NaN                NaN     NaN
# BJ0000616623         0.500       NaN                NaN     NaN
# BJ0000617419         0.500       NaN                NaN     NaN
# BJ0000617545         0.125       NaN                NaN     NaN
# BJ0000617766         0.500       NaN                NaN     NaN
# BJCP90705860         0.500       NaN                NaN     NaN
# BJCY85946155         0.429       NaN                NaN     NaN
# BJDX84450717         0.500       NaN                NaN     NaN
# BJFT56451688         0.048       NaN                NaN     NaN
# BJFT56451692         0.048       NaN                NaN     NaN
# BJFT56451700         0.048       NaN                NaN     NaN
# BJFT61627746         0.048       NaN                NaN     NaN
# BJFT85355966         0.500       NaN                NaN     NaN
# BJHD84636270         0.375       NaN                NaN     NaN
# BJHD84693304         0.333       NaN                NaN     NaN
# BJHD85046371         0.667       NaN                NaN     NaN
#
#               communityAverage
# id
# BJ0000615040           39492.0
# BJ0000615084           37588.0
# BJ0000615132           38753.0
# BJ0000615138           36923.0
# BJ0000615208           39492.0
# BJ0000615220           36923.0
# BJ0000615222           38753.0
# BJ0000615229           39381.0
# BJ0000615401           36358.0
# BJ0000615438           39492.0
# BJ0000615469           39381.0
# BJ0000615595           38753.0
# BJ0000615621           35181.0
# BJ0000615635           39492.0
# BJ0000615823           36923.0
# BJ0000615998           36358.0
# BJ0000616423           36923.0
# BJ0000616623           36923.0
# BJ0000617419           36358.0
# BJ0000617545           39492.0
# BJ0000617766           37588.0
# BJCP90705860           41055.0
# BJCY85946155           74411.0
# BJDX84450717           33298.0
# BJFT56451688           43567.0
# BJFT56451692           43567.0
# BJFT56451700           43567.0
# BJFT61627746           43567.0
# BJFT85355966           46572.0
# BJHD84636270           98686.0
# BJHD84693304          103097.0
# BJHD85046371          103097.0

# %% [markdown]
# #### What we got so far:
# - According to Pandas' document, **The 50 percentile is the same as the median**. That is, if we look at the `temp2_null.describe()` above, the distribution of the '*communityAverage*' column is skewed to the right (mean > median); in the original data set, the mean of the communityAverage is 63682.446305 and the median is 59015.000000, meaning that in the original data set, the distribution of the communityAverage is also skewed to the right.
# - The instances containing the NaN values (regardless the DOM column) mainly fall on the left side of the distribution of the original data set respect to the communityAverage column. One potential reason why these instances fall in the lower communityAverate price zone is that these properties are located in the suburb area. We will verify this hypothesis later when we make the lng/lat agains the total price and the community price.
# - Subway explanation is not provided by the uploader of the data set. I selected several instances and went into the original pages tried to find some information. The instances with NaN values in the subway column that I looked, there were no information about the subway condition, and on the map these properties are far away from major public transportations. The instances with value 1 in the subway column generally have subway station nearby and the distances are less than 1000m from the properties to nearest subway station. Those has value 0 in the subway column, in the original webpage, they ether have no information about the nearby subway or the nearest subway station is more than 1000m away.Consider there are only 32 instances containing NaN value in the subway column. I'm considering either set these value to 0 or simply remove them from the dataset.
# - In `temp3_null` we can see that the instances with no *elevator, fiveYearsProperty, subway* informations are the same instances. Interesting thing is that the buildingType column, these 32 instances has value less than 1. Which is bizarre, because in the column explanation: buildingType: including tower( 1 ) , bungalow( 2 )，combination of plate and tower( 3 ), plate( 4 ). I think these data are bad data. since 32 is a very small number compare to 318851, I believe it is safe to remove these instances from the original dataset.

# %% [markdown]
# ### Data Cleaning

# %%
# as promised previously, i will drop the instances with buildingType value smaller than 1.
df = df.dropna(axis=0, subset=['elevator'])
df.shape
# Out:
# (318819, 24)

# %%
# now let's take a look at the geographical information of the data.
# because the original dataset is way to large, I will sample some instances to plot it, n=10000
smpl = df.sample(n=10000, random_state=1)

smpl.plot(kind="scatter", x="Lng", y='Lat', alpha=0.2, s=(smpl['square']/3)**1.3, label='square', c='price', cmap=plt.get_cmap('hot'), colorbar=True, figsize=(15, 12))
plt.title('Sample Home Price Map')
plt.legend()
plt.show()

# %% [markdown]
# #### There are many things going on in the image:
# 1. each circle is a property instances and the location on the axis represents the actual location of the property on the map (with the longitude and latitude information).
# 2. the size of the circle represents the size (square meters) of the property sold.
# 3. the heatmap is showing the price per square meter of the property. The lighter the color is, the higher price per square meter the property is.
# 4. the empty area in the middle of the image is the "heart" of Beijing, which is where the government facilities located (that's why no homes for sale around the area).
# 5. notice the top part of the government owned area is slightly more price (yellower) than the bottom part. This is because those two areas are the district of finance and commerce.
# 6. the 'spikes' are subway lines. The further away from the center of beijing, the lower the price per square meter. also notice that the circle sizes near the subway lines are generally smaller than the other areas. This should be because there are mainly apartment complex in the area, which these home owners are mainly relying on public transportation when they need to go out.'
# 7. there are some pretty large properties located near the "heart" of Beijing. I'm not surprised because there are some really wealthy people living there since Beijing is the capital of China.
# 8. on the north side of the circle, there is an very dark area has many properties and relatively low per square meter price. This area is near the subway line 13 and 15. These two lines were built after 2010. It is less convenient for living (less shops and other entertainment places). I lived near the area shortly before.

# %%
# here is a map for Beijing subway as an illustration of the location associate with the image we plotted previously.
figure(num=None, figsize=(12, 12), dpi=80)

img=mpimg.imread('subway.jpg')
imgplot = plt.imshow(img, aspect='equal')
plt.show()

# %%
# I viewed the data set in Excel and realized in some columns the data contains Chinese charactors, 
# which after writing into Pandas DataFrame they become some random charactors. 
# for example in the 'floor' column, there are characters "高，中，低" meaning "High, Mid, Low". 
# It follows by the exact floor number. 
# I believe I can safely remove these Chinese characters without loosing information of the data.
df['floor'] = df.floor.str.replace('^[^\d]*', '').astype(float)

# change livingRoom and drawingRoom columns from object type to float type
df['livingRoom'] = df.livingRoom.astype(float)
df['drawingRoom'] = df.drawingRoom.astype(float)
df['bathRoom'] = df.bathRoom.astype(float)

# %%
# now we have tradeTime and constructionTime columns are object type,
# since these are time series information, we will leave them as is for now.
# also the DOM, buildingType, and communityAverage columns still have null values,
# we will fix them now.
temp4 = df[['Lat', 'Lng', 'DOM', 'buildingType', 'communityAverage', 'price', 'totalPrice', 'square', 'livingRoom', 'drawingRoom', 'bathRoom', 'renovationCondition', 'district']]
building_null = temp4[pd.isnull(temp4[['buildingType']]).any(axis=1)]
community_null = temp4[pd.isnull(temp4[['communityAverage']]).any(axis=1)]
print(building_null.shape, community_null.shape)
# Out:
# (2021, 13) (463, 13)

# %%
# notice there are two significant outliers here. Let's take a look at these two guys.
sns.pairplot(building_null[['price', 'totalPrice', 'square', 'district', 'bathRoom']])

# %%
# Let's take a look at the two significant outliers
building_null[building_null['totalPrice'] >= 10000]
# Out:
#                     Lat         Lng   DOM  buildingType  communityAverage  \
# id
# 101101209445  40.002373  116.447681  32.0           NaN          108901.0
# 101101263750  39.978995  116.468806  29.0           NaN           88345.0
#
#                price  totalPrice  square  livingRoom  drawingRoom  bathRoom  \
# id
# 101101209445  128036     11600.0   906.0         6.0          3.0       5.0
# 101101263750  103868     18130.0  1745.5         6.0          3.0       4.0
#
#               renovationCondition  district
# id
# 101101209445                    4         7
# 101101263750                    1         7

# %%
# I double checked the home information, these are luxury townhomes / houses. 
# they are located near the center area of beijing but are very large in size and high in prices.
print(beijing[beijing['id'] == '101101209445']['url'])
print(beijing[beijing['id'] == '101101263750']['url'])
# Out:
# 65440    https://bj.lianjia.com/chengjiao/101101209445....
# Name: url, dtype: object
# 67868    https://bj.lianjia.com/chengjiao/101101263750....
# Name: url, dtype: object

# %%
# how the pairplot looks like without these two extreme instances
no_outliers = building_null[building_null['totalPrice'] < 10000]
sns.pairplot(no_outliers[['price', 'totalPrice', 'square', 'district', 'bathRoom']])

# %%
# from this pairplot we know that these properties without buildingType information fall into the lower price zone.
# majority of the properties are located in district 6 and district 7. 
# Let's take a look at how the price and square feet information look like in these two districts.
# from pairplot we can tell that in the subset of the data, district 7 has way higher total price
# But the price per square meter distributed relatively evenly.
# This is proved by the following plot, that district 7 is generally more pricy compare to district 6.
six = df[df.district == 6]
seven = df[df.district == 7]

six.plot(kind="scatter", x="Lng", y='Lat', alpha=0.2, s=(six['square']/5)**1.1, label='square', c='price', cmap=plt.get_cmap('hot'), colorbar=True, figsize=(7, 5))
plt.title('District 6')
seven.plot(kind="scatter", x="Lng", y='Lat', alpha=0.2, s=(seven['square']/5)**1.1, label='square', c='price', cmap=plt.get_cmap('hot'), colorbar=True, figsize=(7, 5))
plt.title('District 7')
plt.show()

# %%
# see how the price and totalPrice is distributed of the whole dataset
sns.distplot(df['price'])
plt.title('Distribution of Price / Sqr Meter')
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df['totalPrice'])
plt.title('Distribution of Property Price')
plt.show()

# %%
# where each district located
plt.figure(figsize=(10,9))
sns.scatterplot(x="Lng", y="Lat", hue="district", legend="full", palette="Paired", data=smpl)
plt.title("District Map and their Price per Square Meter")
plt.show()

# %%
community_null.groupby(['district'])['district'].count()
# Out:
# district
# 1     141
# 2      14
# 4       7
# 5       1
# 6      30
# 7      71
# 8      20
# 9       1
# 10    165
# 11      4
# 12      2
# 13      7
# Name: district, dtype: int64

# %%
community_null.groupby(['renovationCondition', 'district'])['renovationCondition'].count()
# Out:
# renovationCondition  district
# 1                    1            88
#                      2             5
#                      4             3
#                      5             1
#                      6            17
#                      7            32
#                      8             4
#                      9             1
#                      10          115
#                      11            1
#                      13            2
# 2                    1             8
#                      4             1
#                      7             2
#                      10            7
# 3                    1            28
#                      2             4
#                      4             1
#                      6             5
#                      7            12
#                      8             4
#                      10           32
#                      11            1
#                      12            2
#                      13            1
# 4                    1            17
#                      2             5
#                      4             2
#                      6             8
#                      7            25
#                      8            12
#                      10           11
#                      11            2
#                      13            4
# Name: renovationCondition, dtype: int64

# %%
sns.distplot(community_null['price'])
plt.title('Distribution of Price / Sqr Meter for Instances without community average price info')
plt.show()

# %%
sns.distplot(community_null['square'])
plt.title('Distribution of home size for Instances without community average price info')
plt.show()

# %%
community_null.describe()
# Out:
#               Lat         Lng         DOM  buildingType  communityAverage  \
# count  463.000000  463.000000  217.000000    350.000000               0.0
# mean    39.939988  116.405950   20.746544      2.962857               NaN
# std      0.066997    0.071972   44.456547      1.170944               NaN
# min     39.627030  116.117019    1.000000      1.000000               NaN
# 25%     39.900403  116.368574    1.000000      2.000000               NaN
# 50%     39.936943  116.404534    1.000000      4.000000               NaN
# 75%     39.950849  116.427882   16.000000      4.000000               NaN
# max     40.226319  116.703234  270.000000      4.000000               NaN
#
#                price   totalPrice      square  livingRoom  drawingRoom  \
# count     463.000000   463.000000  463.000000  463.000000   463.000000
# mean    69426.323974   275.237797   54.718726    1.708423     0.725702
# std     41489.167260   252.107060   56.312664    0.918352     0.634786
# min         2.000000     0.100000    6.900000    1.000000     0.000000
# 25%     33927.000000   145.000000   16.335000    1.000000     0.000000
# 50%     55989.000000   200.000000   49.320000    1.000000     1.000000
# 75%    108950.000000   320.000000   79.755000    2.000000     1.000000
# max    149442.000000  2700.000000  922.700000    9.000000     3.000000
#
#          bathRoom  renovationCondition    district
# count  463.000000           463.000000  463.000000
# mean     0.732181             1.984881    6.170626
# std      0.589942             1.233457    3.914542
# min      0.000000             1.000000    1.000000
# 25%      0.000000             1.000000    1.000000
# 50%      1.000000             1.000000    7.000000
# 75%      1.000000             3.000000   10.000000
# max      3.000000             4.000000   13.000000

# %%
# I sampled several instances and checked the webpage with their information. 
# Some of them are regular condos, some are historical buildings, 
# some are shopes, some are very large single family homes.
# The distribution of the price for this subset looks very different from the population distribution.
# I think this might be associate with government policy for limiting the purchase of luxuary homes.
# It is possible for some larger homes, the sales persons don't want to label much information for some large properties.

# notice that majority of these unlabeled community average price information properties are 
# located in district 1 and district 10. There are a lot of very old communities in these two districts.
# It's possible that it is very hard to evaluate these communities' average price.
# The rennovation condition proved this assumption, 
# notice there are 115/463 of total instances are in district 10 with renovation condition score 1 (very bad condition).
# and 88/463 of total instances are in district 1 with renovation condition score 1

# %%
df.groupby(['district'])['district'].count().plot(kind='bar')
plt.title("Histgram of instances for each district")
plt.show()

# %%
# I will estimate community average price for district 1 and district 10. 
# and drop the rest of the instances since they fairly a small amount
df[df['district'] == 1]['communityAverage'].fillna(df[df['district'] == 1]['communityAverage'].mean(), inplace=True)
df[df['district'] == 10]['communityAverage'].fillna(df[df['district'] == 10]['communityAverage'].mean(), inplace=True)

df=df[df['communityAverage'].notnull()]
df.info()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# <class 'pandas.core.frame.DataFrame'>
# Index: 318356 entries, 101084782030 to BJYZ92363553
# Data columns (total 24 columns):
# Lng                    318356 non-null float64
# Lat                    318356 non-null float64
# Cid                    318356 non-null int64
# tradeTime              318356 non-null datetime64[ns]
# DOM                    160632 non-null float64
# followers              318356 non-null int64
# totalPrice             318356 non-null float64
# price                  318356 non-null int64
# square                 318356 non-null float64
# livingRoom             318356 non-null float64
# drawingRoom            318356 non-null float64
# kitchen                318356 non-null int64
# bathRoom               318356 non-null float64
# floor                  318356 non-null float64
# buildingType           316448 non-null float64
# constructionTime       318356 non-null int64
# renovationCondition    318356 non-null int64
# buildingStructure      318356 non-null int64
# ladderRatio            318356 non-null float64
# elevator               318356 non-null float64
# fiveYearsProperty      318356 non-null float64
# subway                 318356 non-null float64
# district               318356 non-null int64
# communityAverage       318356 non-null float64
# dtypes: datetime64[ns](1), float64(15), int64(8)
# memory usage: 60.7+ MB

# %%
# now we are going fix the building type
df.groupby(['buildingType'])['buildingType'].count().plot(kind='bar')
plt.title("Histgram of instances for each building type")
plt.show()

# %%
# This is pretty weird, it seems like there is no building being labeled as bungalow. 
# But when I was clearning the community average price column,
# there were at least several properties should be labeled as bungalow.
building_null.plot(kind="scatter", x="Lng", y='Lat', alpha=0.2, s=(building_null['square']/5)**1.1, label='square', c='price', cmap=plt.get_cmap('hot'), colorbar=True, figsize=(10, 7))
plt.title('Properties with No BuildingType Information')
# Out:
# Text(0.5, 1.0, 'Properties with No BuildingType Information')

# %%
building_null.groupby(['district'])['district'].count().plot(kind='bar')
plt.title("Histgram of instances without buildingtype info for each district")
plt.show()

# %%
# district 3, 5, 6, 13 has significantly more unknown building type properties 
# compare to the original distribution proportionally.
# these 4 districts are located in the suburb area of Beijing city. 
# I will bench mark with price column and define (price >= 60000) to be 5 and (price < 60000) to be 2.
df.loc[df.price >= 60000,'buildingType'] = df.loc[df.price >= 60000,'buildingType'].fillna(5)
df.loc[df.price < 60000,'buildingType'] = df.loc[df.price < 60000,'buildingType'].fillna(2)

# %%
# double check is everything is good
df.describe()
# Out:
#                  Lng            Lat           Cid            DOM  \
# count  318356.000000  318356.000000  3.183560e+05  160632.000000
# mean      116.418501      39.949607  1.129141e+12      28.837579
# std         0.112078       0.092016  2.365283e+12      50.246655
# min       116.072514      39.627030  1.111027e+12       1.000000
# 25%       116.344985      39.893200  1.111027e+12       1.000000
# 50%       116.416780      39.934527  1.111027e+12       7.000000
# 75%       116.477613      40.003018  1.111027e+12      37.000000
# max       116.732378      40.252758  1.114620e+15    1677.000000
#
#            followers     totalPrice          price         square  \
# count  318356.000000  318356.000000  318356.000000  318356.000000
# mean       16.740178     349.158883   43495.408973      83.282881
# std        34.207950     230.730628   21644.037400      37.184298
# min         0.000000       0.100000       1.000000       7.370000
# 25%         0.000000     205.000000   28048.750000      57.920000
# 50%         5.000000     294.000000   38726.000000      74.290000
# 75%        18.000000     426.000000   53788.000000      98.740000
# max      1143.000000   18130.000000  156250.000000    1745.500000
#
#           livingRoom    drawingRoom        ...          buildingType  \
# count  318356.000000  318356.000000        ...         318356.000000
# mean        2.010809       1.172599        ...              3.005346
# std         0.776514       0.521830        ...              1.268840
# min         0.000000       0.000000        ...              1.000000
# 25%         1.000000       1.000000        ...              1.000000
# 50%         2.000000       1.000000        ...              4.000000
# 75%         2.000000       1.000000        ...              4.000000
# max         9.000000       5.000000        ...              5.000000
#
#        constructionTime  renovationCondition  buildingStructure   ladderRatio  \
# count     318356.000000        318356.000000      318356.000000  3.183560e+05
# mean        1999.192486             2.607477           4.452760  6.326258e+01
# std            8.543728             1.311472           1.901505  2.508799e+04
# min         1933.000000             1.000000           1.000000  1.400000e-02
# 25%         1994.000000             1.000000           2.000000  2.500000e-01
# 50%         2001.000000             3.000000           6.000000  3.330000e-01
# 75%         2005.000000             4.000000           6.000000  5.000000e-01
# max         2016.000000             4.000000           6.000000  1.000940e+07
#
#             elevator  fiveYearsProperty         subway       district  \
# count  318356.000000      318356.000000  318356.000000  318356.000000
# mean        0.577567           0.645764       0.600915       6.764154
# std         0.493947           0.478282       0.489711       2.810366
# min         0.000000           0.000000       0.000000       1.000000
# 25%         0.000000           0.000000       0.000000       6.000000
# 50%         1.000000           1.000000       1.000000       7.000000
# 75%         1.000000           1.000000       1.000000       8.000000
# max         1.000000           1.000000       1.000000      13.000000
#
#        communityAverage
# count     318356.000000
# mean       63684.226787
# std        22328.807086
# min        10847.000000
# 25%        46339.000000
# 50%        59015.000000
# 75%        75950.000000
# max       183109.000000
#
# [8 rows x 23 columns]

# %%
no_DOM = df[pd.isnull(df[['DOM']]).any(axis=1)]

# %%
no_DOM.groupby(['district'])['district'].count().plot(kind='bar')
plt.title("Histgram of instances without DOM info for each district")
plt.show()

# %%
no_DOM = no_DOM.sort_values(['tradeTime'])

plt.figure(figsize=(15,8))
ax = no_DOM.groupby(['tradeTime'])['tradeTime'].count().plot(title='Number of Home sales (without DOM info) correspending to trade date')
ax.xaxis.set_major_locator(matplotlib.dates.MonthLocator(interval=6))
ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%Y-%m-%d'))
plt.show()

# %%
plt.figure(figsize=(15,8))
ax1 = no_DOM[no_DOM['tradeTime'] > '2011-01-01'].groupby(['tradeTime'])['tradeTime'].count().plot(title='Number of Home sales (without DOM info) correspending to trade date')
ax2 = (no_DOM[no_DOM['tradeTime'] > '2011-01-01'].groupby(['tradeTime'])['price'].mean()/100).plot()
ax1.xaxis.set_major_locator(matplotlib.dates.MonthLocator(interval=6))
ax1.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%Y-%m-%d'))
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,8))
ax1 = df[df['tradeTime'] > '2011-01-01'].groupby(['tradeTime'])['tradeTime'].count().plot(title='Number of Home sales (all) correspending to trade date')
ax2 = (df[df['tradeTime'] > '2011-01-01'].groupby(['tradeTime'])['price'].mean()/100).plot()
ax1.xaxis.set_major_locator(matplotlib.dates.MonthLocator(interval=6))
ax1.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%Y-%m-%d'))
plt.legend()
plt.show()

# %% [markdown]
# #### The Peaks:
# While the price is generally going up, the trade happens with peaks. policy changes (new laws):
# 1. **2013-02-20:** 新国五条，是指在2013年2月20日国务院常务会议确定的五项加强房地产市场调控的政策措施。国务院常务会议出台五项调控政策措施，要求各直辖市、计划单列市和除拉萨外的省会城市要按照保持房价基本稳定的原则，制定并公布年度新建商品住房价格控制目标，建立健全稳定房价工作的考核问责制度。北京自3月31日起禁止京籍单身人士购买二套房;严格按个人转让住房所得的20%征收个人所得税,出售五年以上唯一住房免征个税;进一步提高二套房贷首付款比例;新旧政策以买卖合同网签时间为准。(baidu百科）
# 2. **2014-09-30**: 2014年“930新政”的出台，即被认为是第四次大宽松开启。央行松绑“限贷”，购买首套普通住房贷款最低首付款比例为30%，利率下限为贷款基准利率的0.7倍；有1套住房并已结清的，再次贷款购买普通商品住房，执行首套房贷款政策。政策出台后，楼市并没有稳定住。（凤凰财经）
# 3. **2016-02-22**： “222新政“调整房地产交易环节契税。（国家税务总局）
# 4. **2016-05-01**： “营改增”实施，营业税改增值税，简称营改增，是指以前缴纳营业税的应税项目改成缴纳增值税。营改增的最大特点是减少重复征税，可以促使社会形成更好的良性循环，有利于企业降低税负。（baidu百科）
#
# The instances without DOM information has very close pattern with the total data set. The new law introduced would cause fluctuation of the market. What surprised me is that these new laws may cause strong fluctuations in terms of number of sales, but the price for the properties are increading in a relatively smooth way.
# I don't think there is a strong correlation between DOM and the price. So let's verify my hypothesis.

# %%
DOM_nn = df[df['DOM'].notnull()]
DOM_nn.plot.scatter(x='DOM', y='price')
plt.title('DOM against Price')
plt.show()

# %%
# except for the several very large DOM instances (possibly because the house in bad condition), 
# I don't think DOM is a strong feature for predicting the home price.
# I will drop this column for the analysis.
# However, if my prediction isnt very satisfying without DOM information, I'll consider add it back.
df.drop(['DOM'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 318356 entries, 101084782030 to BJYZ92363553
# Data columns (total 23 columns):
# Lng                    318356 non-null float64
# Lat                    318356 non-null float64
# Cid                    318356 non-null int64
# tradeTime              318356 non-null datetime64[ns]
# followers              318356 non-null int64
# totalPrice             318356 non-null float64
# price                  318356 non-null int64
# square                 318356 non-null float64
# livingRoom             318356 non-null float64
# drawingRoom            318356 non-null float64
# kitchen                318356 non-null int64
# bathRoom               318356 non-null float64
# floor                  318356 non-null float64
# buildingType           318356 non-null float64
# constructionTime       318356 non-null int64
# renovationCondition    318356 non-null int64
# buildingStructure      318356 non-null int64
# ladderRatio            318356 non-null float64
# elevator               318356 non-null float64
# fiveYearsProperty      318356 non-null float64
# subway                 318356 non-null float64
# district               318356 non-null int64
# communityAverage       318356 non-null float64
# dtypes: datetime64[ns](1), float64(14), int64(8)
# memory usage: 68.3+ MB

# %%
plt.figure(figsize=(15,8))
df.groupby(['constructionTime'])['constructionTime'].count().plot(kind='bar')
plt.title("Histgram of construction time (missing values temporarily set to mean (rounded up) of the district group)")
plt.show()

# %%
# there isn't an obvious trend in terms of construction time with the price
df.plot.scatter(x='constructionTime', y='price', alpha=0.2)
plt.title('construction time against Price')
plt.show()

# %%
# this seems reasonable, district 1 and 10 are around the tiananmen square.
# district 7 and 8 are the financial/cermercial district and where large companies' HQ located
df.groupby(['district'])['communityAverage'].mean().plot(kind='bar')
plt.title("Histgram of community average")
plt.show()

# %%
df.head()
# Out:
#                      Lng        Lat            Cid  tradeTime  followers  \
# id
# 101084782030  116.475489  40.019520  1111027376244 2016-08-09        106
# 101086012217  116.453917  39.881534  1111027381879 2016-07-28        126
# 101086041636  116.561978  39.877145  1111040862969 2016-12-11         48
# 101086406841  116.438010  40.076114  1111043185817 2016-09-30        138
# 101086920653  116.428392  39.886229  1111027381174 2016-08-28        286
#
#               totalPrice  price  square  livingRoom  drawingRoom  \
# id
# 101084782030       415.0  31680  131.00         2.0          1.0
# 101086012217       575.0  43436  132.38         2.0          2.0
# 101086041636      1030.0  52021  198.00         3.0          2.0
# 101086406841       297.5  22202  134.00         3.0          1.0
# 101086920653       392.0  48396   81.00         2.0          1.0
#
#                     ...         buildingType  constructionTime  \
# id                  ...
# 101084782030        ...                  1.0              2005
# 101086012217        ...                  1.0              2004
# 101086041636        ...                  4.0              2005
# 101086406841        ...                  1.0              2008
# 101086920653        ...                  4.0              1960
#
#               renovationCondition  buildingStructure  ladderRatio  elevator  \
# id
# 101084782030                    3                  6        0.217       1.0
# 101086012217                    4                  6        0.667       1.0
# 101086041636                    3                  6        0.500       1.0
# 101086406841                    1                  6        0.273       1.0
# 101086920653                    2                  2        0.333       0.0
#
#               fiveYearsProperty  subway  district  communityAverage
# id
# 101084782030                0.0     1.0         7           56021.0
# 101086012217                1.0     0.0         7           71539.0
# 101086041636                0.0     0.0         7           48160.0
# 101086406841                0.0     0.0         6           51238.0
# 101086920653                1.0     1.0         1           62588.0
#
# [5 rows x 23 columns]

# %%
price_group = pd.DataFrame(df.groupby([pd.Grouper(key='tradeTime', freq='Y'), 'district'])['price'].mean().reset_index(name='avg_price'))

# %%
price_group.head(2)
# Out:
#    tradeTime  district  avg_price
# 0 2002-12-31         6    17053.0
# 1 2002-12-31         7    20625.5

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='tradeTime', y='avg_price', hue='district', data=price_group, palette='Paired', legend='full')
plt.title('Median Price Change of Each District')
plt.show();

# %%
sales_count = pd.DataFrame(df.groupby([pd.Grouper(key='tradeTime', freq='Y'), 'district'])['price'].count().reset_index(name='sales_count'))
sales_count.head()
# Out:
#    tradeTime  district  sales_count
# 0 2002-12-31         6            1
# 1 2002-12-31         7            2
# 2 2003-12-31         2            1
# 3 2008-12-31         6            1
# 4 2009-12-31        10            1

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='tradeTime', y='sales_count', hue='district', data=sales_count, palette='Paired', legend='full')
plt.title('Sales Trand of Each District')
plt.show();

# %% [markdown]
# ### Preparing Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
X = df[['Lng', 'Lat', 'Cid', 'followers', 'price', 
        'square', 'livingRoom', 'drawingRoom', 'kitchen', 'bathRoom', 'floor', 
        'buildingType', 'constructionTime', 'renovationCondition', 'buildingStructure', 
        'ladderRatio', 'elevator', 'fiveYearsProperty', 'subway', 'district', 'communityAverage']]
y = df['totalPrice']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42, stratify=df.district)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (191013, 21) (127343, 21) (191013,) (127343,)

# %%
X_train.head(2)
# Out:
#                      Lng        Lat            Cid  followers  price  square  \
# id
# 101101528331  116.353023  39.882240  1111027380688          0  66482   108.0
# BJFT88991821  116.308652  39.892397  1111027382193          8  42083    92.2
#
#               livingRoom  drawingRoom  kitchen  bathRoom        ...         \
# id                                                              ...
# 101101528331         2.0          2.0        1       1.0        ...
# BJFT88991821         2.0          2.0        1       1.0        ...
#
#               buildingType  constructionTime  renovationCondition  \
# id
# 101101528331           1.0              2002                    1
# BJFT88991821           1.0              2000                    4
#
#               buildingStructure  ladderRatio  elevator  fiveYearsProperty  \
# id
# 101101528331                  6         0.25       1.0                0.0
# BJFT88991821                  6         0.20       1.0                0.0
#
#               subway  district  communityAverage
# id
# 101101528331     0.0        10           66778.0
# BJFT88991821     1.0         2           64808.0
#
# [2 rows x 21 columns]

# %%
# Linear Regression
lrr = LinearRegression()

lr = lrr.fit(X_train, y_train)
lr_predict = lr.predict(X_test)

print("Linear Regression Score: ", lr.score(X_test, y_test))
# Out:
# Linear Regression Score:  0.8632534230851554

# %%
# Decision Tree Regression
dtr = DecisionTreeRegressor()
dt = dtr.fit(X_train, y_train)

dt_predict = dt.predict(X_test)

print("Decision Tree Score: ", dt.score(X_test, y_test))
# Out:
# Decision Tree Score:  0.9905115968697673

# %%
83.09
# Out:
# 83.09
